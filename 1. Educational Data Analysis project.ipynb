# %%
#import python libraries
import pandas as pd
import numpy as np
import random
import string

# %%
df = pd.read_csv("EdStatsCountry.csv") #Using this code we can upload the data
df.head(5) #Displays the first 5 rows of df.
# Out:
#   Country_Code   Short_Name                     Long_Name 2-alpha_code  \
# 0          ABW        Aruba                         Aruba           AW
# 1          AFG  Afghanistan  Islamic State of Afghanistan           AF
# 2          AGO       Angola   People's Republic of Angola           AO
# 3          ALB      Albania           Republic of Albania           AL
# 4          AND      Andorra       Principality of Andorra           AD
#
#     Currency_Unit                     Region          Income_Group WB-2_code  \
# 0   Aruban florin  Latin America & Caribbean  High income: nonOECD        AW
# 1  Afghan afghani                 South Asia            Low income        AF
# 2  Angolan kwanza         Sub-Saharan Africa   Upper middle income        AO
# 3    Albanian lek      Europe & Central Asia   Upper middle income        AL
# 4            Euro      Europe & Central Asia  High income: nonOECD        AD
#
#                          National_accounts_base_year  \
# ...

# %%
df.shape #Show the how many column & row idividual in the particular table
# Out:
# (239, 29)

# %%
df.columns #Returns the list of column names
# Out:
# Index(['Country_Code', 'Short_Name', 'Long_Name', '2-alpha_code',
#        'Currency_Unit', 'Region', 'Income_Group', 'WB-2_code',
#        'National_accounts_base_year', 'National_accounts_reference_year',
#        'SNA_price_valuation', 'Lending_category', 'Other_groups',
#        'System_of_National_Accounts', 'Alternative_conversion_factor',
#        'PPP_survey_year', 'Balance_of_Payments_Manual_in_use',
#        'External_debt_Reporting_status', 'System_of_trade',
#        'Government_Accounting_concept', 'IMF_data_dissemination_standard',
#        'Latest_population_census', 'Latest_household_survey',
#        'Source_of_most_recent_Income_and_expenditure_data',
#        'Vital_registration_complete', 'Latest_agricultural_census',
#        'Latest_industrial_ data', 'Latest_trade_data',
#        'Latest_water_withdrawal_data'],
#       dtype='object')

# %%
df.info() #That will print information on all the columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 29 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country_Code                                       239 non-null    object
#  1   Short_Name                                         239 non-null    object
#  2   Long_Name                                          239 non-null    object
#  3   2-alpha_code                                       238 non-null    object
#  4   Currency_Unit                                      239 non-null    object
#  5   Region                                             239 non-null    object
#  6   Income_Group                                       239 non-null    object
#  7   WB-2_code                                          238 non-null    object
#  8   National_accounts_base_year                        239 non-null    object
# ...

# %%
df['Income_Group'].unique() #Show all type of "Income_Group" name
# Out:
# array(['High income: nonOECD', 'Low income', 'Upper middle income',
#        'Lower middle income', 'High income: OECD'], dtype=object)

# %% [markdown]
# # Data Filtering

# %%
#Filters 'df' for rows where 'Income_Group' is 'Upper middle income'.
df_recet = df[df['Income_Group'] == 'Upper middle income']

# Preview the first few rows of 'df_recet'
df_recet.head()
# Out:
#    Country_Code      Short_Name                    Long_Name 2-alpha_code  \
# 2           AGO          Angola  People's Republic of Angola           AO
# 3           ALB         Albania          Republic of Albania           AL
# 7           ARG       Argentina           Argentine Republic           AR
# 9           ASM  American Samoa               American Samoa           AS
# 13          AZE      Azerbaijan       Republic of Azerbaijan           AZ
#
#       Currency_Unit                     Region         Income_Group WB-2_code  \
# 2    Angolan kwanza         Sub-Saharan Africa  Upper middle income        AO
# 3      Albanian lek      Europe & Central Asia  Upper middle income        AL
# 7    Argentine peso  Latin America & Caribbean  Upper middle income        AR
# 9       U.S. dollar        East Asia & Pacific  Upper middle income        AS
# 13  New Azeri manat      Europe & Central Asia  Upper middle income        AZ
#
# ...

# %%
df_recet["Income_Group"].value_counts() #Counts 'Income_Group' in df_recet.
# Out:
# Income_Group
# Upper middle income    63
# Name: count, dtype: int64

# %%
df_recet =df_recet.reset_index(drop=True) #Resets 'df_recet' index.
df_recet.head() #Displays the first 5 rows of df_recet.
# Out:
#   Country_Code      Short_Name                    Long_Name 2-alpha_code  \
# 0          AGO          Angola  People's Republic of Angola           AO
# 1          ALB         Albania          Republic of Albania           AL
# 2          ARG       Argentina           Argentine Republic           AR
# 3          ASM  American Samoa               American Samoa           AS
# 4          AZE      Azerbaijan       Republic of Azerbaijan           AZ
#
#      Currency_Unit                     Region         Income_Group WB-2_code  \
# 0   Angolan kwanza         Sub-Saharan Africa  Upper middle income        AO
# 1     Albanian lek      Europe & Central Asia  Upper middle income        AL
# 2   Argentine peso  Latin America & Caribbean  Upper middle income        AR
# 3      U.S. dollar        East Asia & Pacific  Upper middle income        AS
# 4  New Azeri manat      Europe & Central Asia  Upper middle income        AZ
#
#                          National_accounts_base_year  \
# ...

# %%
df_recet.Country_Code #Accesses the Country_Code column from df_recet.
# Out:
# 0     AGO
# 1     ALB
# 2     ARG
# 3     ASM
# 4     AZE
#      ...
# 58    TUR
# 59    TUV
# 60    VCT
# 61    VEN
# 62    ZAF
# Name: Country_Code, Length: 63, dtype: object

# %%
df_recet["Region"].value_counts() #Counts the unique values in the Region column of 'df_recet'.
# Out:
# Region
# Latin America & Caribbean     23
# Europe & Central Asia         15
# East Asia & Pacific            9
# Sub-Saharan Africa             8
# Middle East & North Africa     7
# South Asia                     1
# Name: count, dtype: int64

# %%
df_recet.Region #Accesses the 'Region' column in 'df_recet'.
# Out:
# 0            Sub-Saharan Africa
# 1         Europe & Central Asia
# 2     Latin America & Caribbean
# 3           East Asia & Pacific
# 4         Europe & Central Asia
#                 ...
# 58        Europe & Central Asia
# 59          East Asia & Pacific
# 60    Latin America & Caribbean
# 61    Latin America & Caribbean
# 62           Sub-Saharan Africa
# Name: Region, Length: 63, dtype: object

# %%
df_recet.Region.unique() #Returns the unique values in the Region column of 'df_recet'.
# Out:
# array(['Sub-Saharan Africa', 'Europe & Central Asia',
#        'Latin America & Caribbean', 'East Asia & Pacific',
#        'Middle East & North Africa', 'South Asia'], dtype=object)

# %%
df_recet.info() #That will print information on all the columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 29 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country_Code                                       63 non-null     object
#  1   Short_Name                                         63 non-null     object
#  2   Long_Name                                          63 non-null     object
#  3   2-alpha_code                                       62 non-null     object
#  4   Currency_Unit                                      63 non-null     object
#  5   Region                                             63 non-null     object
#  6   Income_Group                                       63 non-null     object
#  7   WB-2_code                                          62 non-null     object
#  8   National_accounts_base_year                        63 non-null     object
# ...

# %% [markdown]
# # Statistical Modeling

# %%
df_recet.describe() #Summarize data such as mean, median, or standard deviation for numeric columns
# Out:
#        National_accounts_reference_year  Latest_industrial_ data  \
# count                         63.000000                63.000000
# mean                        1907.238095              2008.349206
# std                          429.910445                 2.410720
# min                            0.000000              2001.000000
# 25%                         2000.000000              2008.000000
# 50%                         2002.000000              2009.000000
# 75%                         2005.000000              2010.000000
# max                         2012.000000              2010.000000
#
#        Latest_trade_data
# count          63.000000
# mean         2011.317460
# std             1.907755
# min          2000.000000
# 25%          2012.000000
# 50%          2012.000000
# 75%          2012.000000
# max          2012.000000

# %%
# Save the filtered DataFrame as a CSV file
df_recet.to_csv('recet.EdStatsCountry_data.csv', index=False)
