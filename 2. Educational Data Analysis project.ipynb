# %%
#import python libraries
import pandas as pd
import numpy as np
import random
import string

# %%
df = pd.read_csv("EdStatsCountry.csv") #Using this code we can upload the data
df.head(5) #Displays the first 5 rows of df.
# Out:
#   Country_Code   Short_Name   Table_Name                     Long_Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha_code   Currency_Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special_Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
# 4                                                NaN
#
#                       Region          Income_Group WB-2_code  ...  \
# 0  Latin America & Caribbean  High income: nonOECD        AW  ...
# 1                 South Asia            Low income        AF  ...
# 2         Sub-Saharan Africa   Upper middle income        AO  ...
# 3      Europe & Central Asia   Upper middle income        AL  ...
# 4      Europe & Central Asia  High income: nonOECD        AD  ...
#
#      Government_Accounting_concept           IMF_data_dissemination_standard  \
# 0                              NaN                                       NaN
# 1  Consolidated central government  General Data Dissemination System (GDDS)
# 2     Budgetary central government  General Data Dissemination System (GDDS)
# 3     Budgetary central government  General Data Dissemination System (GDDS)
# 4                              NaN                                       NaN
#
#                             Latest_population_census  \
# 0                                               2010
# 1                                               1979
# 2                                               1970
# 3                                               2011
# 4  2011. Population figures compiled from adminis...
#
#                              Latest_household_survey  \
# 0                                                NaN
# 1  Multiple Indicator Cluster Survey (MICS), 2010/11
# 2               Malaria Indicator Survey (MIS), 2011
# 3       Demographic and Health Survey (DHS), 2008/09
# 4                                                NaN
#
#    Source_of_most_recent_Income_and_expenditure_data  \
# 0                                                NaN
# 1            Integrated household survey (IHS), 2008
# 2            Integrated household survey (IHS), 2008
# 3  Living Standards Measurement Study Survey (LSM...
# 4                                                NaN
#
#   Vital_registration_complete Latest_agricultural_census  \
# 0                         Yes                        NaN
# 1                         NaN                    2013/14
# 2                         NaN                       2015
# 3                         Yes                       2012
# 4                         Yes                        NaN
#
#   Latest_industrial_ data Latest_trade_data Latest_water_withdrawal_data
# 0                     NaN            2012.0                          NaN
# 1                     NaN            2012.0                         2000
# 2                     NaN               NaN                         2005
# 3                  2010.0            2012.0                         2006
# 4                     NaN            2006.0                          NaN
#
# [5 rows x 31 columns]

# %%
df.shape #Show the how many column & row idividual in the particular table
# Out:
# (241, 31)

# %%
df.columns #Returns the list of column names in the
# Out:
# Index(['Country_Code', 'Short_Name', 'Table_Name', 'Long_Name', '2-alpha_code',
#        'Currency_Unit', 'Special_Notes', 'Region', 'Income_Group', 'WB-2_code',
#        'National_accounts_base_year', 'National_accounts_reference_year',
#        'SNA_price_valuation', 'Lending_category', 'Other_groups',
#        'System_of_National_Accounts', 'Alternative_conversion_factor',
#        'PPP_survey_year', 'Balance_of_Payments_Manual_in_use',
#        'External_debt_Reporting_status', 'System_of_trade',
#        'Government_Accounting_concept', 'IMF_data_dissemination_standard',
#        'Latest_population_census', 'Latest_household_survey',
#        'Source_of_most_recent_Income_and_expenditure_data',
#        'Vital_registration_complete', 'Latest_agricultural_census',
#        'Latest_industrial_ data', 'Latest_trade_data',
#        'Latest_water_withdrawal_data'],
#       dtype='object')

# %%
df.info() #That will print information on all the columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 31 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country_Code                                       241 non-null    object
#  1   Short_Name                                         241 non-null    object
#  2   Table_Name                                         241 non-null    object
#  3   Long_Name                                          241 non-null    object
#  4   2-alpha_code                                       238 non-null    object
#  5   Currency_Unit                                      215 non-null    object
#  6   Special_Notes                                      145 non-null    object
#  7   Region                                             214 non-null    object
#  8   Income_Group                                       214 non-null    object
#  9   WB-2_code                                          240 non-null    object
#  10  National_accounts_base_year                        205 non-null    object
#  11  National_accounts_reference_year                   32 non-null     float64
#  12  SNA_price_valuation                                197 non-null    object
#  13  Lending_category                                   144 non-null    object
#  14  Other_groups                                       58 non-null     object
#  15  System_of_National_Accounts                        215 non-null    object
#  16  Alternative_conversion_factor                      47 non-null     object
#  17  PPP_survey_year                                    145 non-null    object
#  18  Balance_of_Payments_Manual_in_use                  181 non-null    object
#  19  External_debt_Reporting_status                     124 non-null    object
#  20  System_of_trade                                    200 non-null    object
#  21  Government_Accounting_concept                      161 non-null    object
#  22  IMF_data_dissemination_standard                    181 non-null    object
#  23  Latest_population_census                           213 non-null    object
#  24  Latest_household_survey                            141 non-null    object
#  25  Source_of_most_recent_Income_and_expenditure_data  160 non-null    object
#  26  Vital_registration_complete                        111 non-null    object
#  27  Latest_agricultural_census                         142 non-null    object
#  28  Latest_industrial_ data                            107 non-null    float64
#  29  Latest_trade_data                                  185 non-null    float64
#  30  Latest_water_withdrawal_data                       179 non-null    object
# dtypes: float64(3), object(28)
# memory usage: 58.5+ KB

# %%
df['Income_Group'].unique() #Show all type of movie name
# Out:
# array(['High income: nonOECD', 'Low income', 'Upper middle income', nan,
#        'Lower middle income', 'High income: OECD'], dtype=object)

# %% [markdown]
# # Data Filtering

# %%
# Filter the DataFrame and save it to 'df_remove'
df_remove = df[df['Income_Group'] == 'Upper middle income']

# Preview the first few rows of 'df_remove'
df_remove.head()
# Out:
#    Country_Code      Short_Name      Table_Name                    Long_Name  \
# 2           AGO          Angola          Angola  People's Republic of Angola
# 3           ALB         Albania         Albania          Republic of Albania
# 7           ARG       Argentina       Argentina           Argentine Republic
# 9           ASM  American Samoa  American Samoa               American Samoa
# 13          AZE      Azerbaijan      Azerbaijan       Republic of Azerbaijan
#
#    2-alpha_code    Currency_Unit  \
# 2            AO   Angolan kwanza
# 3            AL     Albanian lek
# 7            AR   Argentine peso
# 9            AS      U.S. dollar
# 13           AZ  New Azeri manat
#
#                                         Special_Notes  \
# 2   April 2013 database update: Based on IMF data,...
# 3                                                 NaN
# 7                                                 NaN
# 9                                                 NaN
# 13  April 2012 database update: National accounts ...
#
#                        Region         Income_Group WB-2_code  ...  \
# 2          Sub-Saharan Africa  Upper middle income        AO  ...
# 3       Europe & Central Asia  Upper middle income        AL  ...
# 7   Latin America & Caribbean  Upper middle income        AR  ...
# 9         East Asia & Pacific  Upper middle income        AS  ...
# 13      Europe & Central Asia  Upper middle income        AZ  ...
#
#       Government_Accounting_concept  \
# 2      Budgetary central government
# 3      Budgetary central government
# 7   Consolidated central government
# 9                               NaN
# 13  Consolidated central government
#
#                IMF_data_dissemination_standard Latest_population_census  \
# 2     General Data Dissemination System (GDDS)                     1970
# 3     General Data Dissemination System (GDDS)                     2011
# 7   Special Data Dissemination Standard (SDDS)                     2010
# 9                                          NaN                     2010
# 13    General Data Dissemination System (GDDS)                     2009
#
#                               Latest_household_survey  \
# 2                Malaria Indicator Survey (MIS), 2011
# 3        Demographic and Health Survey (DHS), 2008/09
# 7   Multiple Indicator Cluster Survey (MICS), 2011/12
# 9                                                 NaN
# 13          Demographic and Health Survey (DHS), 2006
#
#     Source_of_most_recent_Income_and_expenditure_data  \
# 2             Integrated household survey (IHS), 2008
# 3   Living Standards Measurement Study Survey (LSM...
# 7             Integrated household survey (IHS), 2012
# 9                                                 NaN
# 13     Expenditure survey/budget survey (ES/BS), 2012
#
#    Vital_registration_complete Latest_agricultural_census  \
# 2                          NaN                       2015
# 3                          Yes                       2012
# 7                          Yes                       2013
# 9                          Yes                       2007
# 13                         Yes                       2015
#
#    Latest_industrial_ data Latest_trade_data Latest_water_withdrawal_data
# 2                      NaN               NaN                         2005
# 3                   2010.0            2012.0                         2006
# 7                   2002.0            2012.0                         2000
# 9                      NaN               NaN                          NaN
# 13                  2010.0            2012.0                         2005
#
# [5 rows x 31 columns]

# %%
df_remove["Income_Group"].value_counts() #Counts 'Income_Group' in df_remove.
# Out:
# Income_Group
# Upper middle income    55
# Name: count, dtype: int64

# %%
df_remove =df_remove.reset_index(drop=True) #Resets 'df_remove' index.
df_remove.head() #Displays the first 5 rows of df_recet.
# Out:
#   Country_Code      Short_Name      Table_Name                    Long_Name  \
# 0          AGO          Angola          Angola  People's Republic of Angola
# 1          ALB         Albania         Albania          Republic of Albania
# 2          ARG       Argentina       Argentina           Argentine Republic
# 3          ASM  American Samoa  American Samoa               American Samoa
# 4          AZE      Azerbaijan      Azerbaijan       Republic of Azerbaijan
#
#   2-alpha_code    Currency_Unit  \
# 0           AO   Angolan kwanza
# 1           AL     Albanian lek
# 2           AR   Argentine peso
# 3           AS      U.S. dollar
# 4           AZ  New Azeri manat
#
#                                        Special_Notes  \
# 0  April 2013 database update: Based on IMF data,...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  April 2012 database update: National accounts ...
#
#                       Region         Income_Group WB-2_code  ...  \
# 0         Sub-Saharan Africa  Upper middle income        AO  ...
# 1      Europe & Central Asia  Upper middle income        AL  ...
# 2  Latin America & Caribbean  Upper middle income        AR  ...
# 3        East Asia & Pacific  Upper middle income        AS  ...
# 4      Europe & Central Asia  Upper middle income        AZ  ...
#
#      Government_Accounting_concept  \
# 0     Budgetary central government
# 1     Budgetary central government
# 2  Consolidated central government
# 3                              NaN
# 4  Consolidated central government
#
#               IMF_data_dissemination_standard Latest_population_census  \
# 0    General Data Dissemination System (GDDS)                     1970
# 1    General Data Dissemination System (GDDS)                     2011
# 2  Special Data Dissemination Standard (SDDS)                     2010
# 3                                         NaN                     2010
# 4    General Data Dissemination System (GDDS)                     2009
#
#                              Latest_household_survey  \
# 0               Malaria Indicator Survey (MIS), 2011
# 1       Demographic and Health Survey (DHS), 2008/09
# 2  Multiple Indicator Cluster Survey (MICS), 2011/12
# 3                                                NaN
# 4          Demographic and Health Survey (DHS), 2006
#
#    Source_of_most_recent_Income_and_expenditure_data  \
# 0            Integrated household survey (IHS), 2008
# 1  Living Standards Measurement Study Survey (LSM...
# 2            Integrated household survey (IHS), 2012
# 3                                                NaN
# 4     Expenditure survey/budget survey (ES/BS), 2012
#
#   Vital_registration_complete Latest_agricultural_census  \
# 0                         NaN                       2015
# 1                         Yes                       2012
# 2                         Yes                       2013
# 3                         Yes                       2007
# 4                         Yes                       2015
#
#   Latest_industrial_ data Latest_trade_data Latest_water_withdrawal_data
# 0                     NaN               NaN                         2005
# 1                  2010.0            2012.0                         2006
# 2                  2002.0            2012.0                         2000
# 3                     NaN               NaN                          NaN
# 4                  2010.0            2012.0                         2005
#
# [5 rows x 31 columns]

# %%
column_to_check = '2-alpha_code'# Replace 'ema' with the correct column name if it's different

# Generate random 2-letter code only where 'column_to_check' is null
df_remove['2-alpha_code'] = df_remove['2-alpha_code'].where(
    df_remove[column_to_check].notnull(), 
    [''.join(random.choices(string.ascii_uppercase, k=2)) for _ in range(df_remove[column_to_check].isnull().sum())]
)
# Display the updated DataFrame
df_remove.head()
# Out:
#   Country_Code      Short_Name      Table_Name                    Long_Name  \
# 0          AGO          Angola          Angola  People's Republic of Angola
# 1          ALB         Albania         Albania          Republic of Albania
# 2          ARG       Argentina       Argentina           Argentine Republic
# 3          ASM  American Samoa  American Samoa               American Samoa
# 4          AZE      Azerbaijan      Azerbaijan       Republic of Azerbaijan
#
#   2-alpha_code    Currency_Unit  \
# 0           AO   Angolan kwanza
# 1           AL     Albanian lek
# 2           AR   Argentine peso
# 3           AS      U.S. dollar
# 4           AZ  New Azeri manat
#
#                                        Special_Notes  \
# 0  April 2013 database update: Based on IMF data,...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  April 2012 database update: National accounts ...
#
#                       Region         Income_Group WB-2_code  ...  \
# 0         Sub-Saharan Africa  Upper middle income        AO  ...
# 1      Europe & Central Asia  Upper middle income        AL  ...
# 2  Latin America & Caribbean  Upper middle income        AR  ...
# 3        East Asia & Pacific  Upper middle income        AS  ...
# 4      Europe & Central Asia  Upper middle income        AZ  ...
#
#      Government_Accounting_concept  \
# 0     Budgetary central government
# 1     Budgetary central government
# 2  Consolidated central government
# 3                              NaN
# 4  Consolidated central government
#
#               IMF_data_dissemination_standard Latest_population_census  \
# 0    General Data Dissemination System (GDDS)                     1970
# 1    General Data Dissemination System (GDDS)                     2011
# 2  Special Data Dissemination Standard (SDDS)                     2010
# 3                                         NaN                     2010
# 4    General Data Dissemination System (GDDS)                     2009
#
#                              Latest_household_survey  \
# 0               Malaria Indicator Survey (MIS), 2011
# 1       Demographic and Health Survey (DHS), 2008/09
# 2  Multiple Indicator Cluster Survey (MICS), 2011/12
# 3                                                NaN
# 4          Demographic and Health Survey (DHS), 2006
#
#    Source_of_most_recent_Income_and_expenditure_data  \
# 0            Integrated household survey (IHS), 2008
# 1  Living Standards Measurement Study Survey (LSM...
# 2            Integrated household survey (IHS), 2012
# 3                                                NaN
# 4     Expenditure survey/budget survey (ES/BS), 2012
#
#   Vital_registration_complete Latest_agricultural_census  \
# 0                         NaN                       2015
# 1                         Yes                       2012
# 2                         Yes                       2013
# 3                         Yes                       2007
# 4                         Yes                       2015
#
#   Latest_industrial_ data Latest_trade_data Latest_water_withdrawal_data
# 0                     NaN               NaN                         2005
# 1                  2010.0            2012.0                         2006
# 2                  2002.0            2012.0                         2000
# 3                     NaN               NaN                          NaN
# 4                  2010.0            2012.0                         2005
#
# [5 rows x 31 columns]

# %%
column_to_check = 'WB-2_code'# Replace 'ema' with the correct column name if it's different

# Generate random 2-letter code only where 'column_to_check' is null
df_remove['WB-2_code'] = df_remove['WB-2_code'].where(
    df_remove[column_to_check].notnull(), 
    [''.join(random.choices(string.ascii_uppercase, k=2)) for _ in range(df_remove[column_to_check].isnull().sum())]
)
# Display the updated DataFrame
df_remove.head()
# Out:
#   Country_Code      Short_Name      Table_Name                    Long_Name  \
# 0          AGO          Angola          Angola  People's Republic of Angola
# 1          ALB         Albania         Albania          Republic of Albania
# 2          ARG       Argentina       Argentina           Argentine Republic
# 3          ASM  American Samoa  American Samoa               American Samoa
# 4          AZE      Azerbaijan      Azerbaijan       Republic of Azerbaijan
#
#   2-alpha_code    Currency_Unit  \
# 0           AO   Angolan kwanza
# 1           AL     Albanian lek
# 2           AR   Argentine peso
# 3           AS      U.S. dollar
# 4           AZ  New Azeri manat
#
#                                        Special_Notes  \
# 0  April 2013 database update: Based on IMF data,...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  April 2012 database update: National accounts ...
#
#                       Region         Income_Group WB-2_code  ...  \
# 0         Sub-Saharan Africa  Upper middle income        AO  ...
# 1      Europe & Central Asia  Upper middle income        AL  ...
# 2  Latin America & Caribbean  Upper middle income        AR  ...
# 3        East Asia & Pacific  Upper middle income        AS  ...
# 4      Europe & Central Asia  Upper middle income        AZ  ...
#
#      Government_Accounting_concept  \
# 0     Budgetary central government
# 1     Budgetary central government
# 2  Consolidated central government
# 3                              NaN
# 4  Consolidated central government
#
#               IMF_data_dissemination_standard Latest_population_census  \
# 0    General Data Dissemination System (GDDS)                     1970
# 1    General Data Dissemination System (GDDS)                     2011
# 2  Special Data Dissemination Standard (SDDS)                     2010
# 3                                         NaN                     2010
# 4    General Data Dissemination System (GDDS)                     2009
#
#                              Latest_household_survey  \
# 0               Malaria Indicator Survey (MIS), 2011
# 1       Demographic and Health Survey (DHS), 2008/09
# 2  Multiple Indicator Cluster Survey (MICS), 2011/12
# 3                                                NaN
# 4          Demographic and Health Survey (DHS), 2006
#
#    Source_of_most_recent_Income_and_expenditure_data  \
# 0            Integrated household survey (IHS), 2008
# 1  Living Standards Measurement Study Survey (LSM...
# 2            Integrated household survey (IHS), 2012
# 3                                                NaN
# 4     Expenditure survey/budget survey (ES/BS), 2012
#
#   Vital_registration_complete Latest_agricultural_census  \
# 0                         NaN                       2015
# 1                         Yes                       2012
# 2                         Yes                       2013
# 3                         Yes                       2007
# 4                         Yes                       2015
#
#   Latest_industrial_ data Latest_trade_data Latest_water_withdrawal_data
# 0                     NaN               NaN                         2005
# 1                  2010.0            2012.0                         2006
# 2                  2002.0            2012.0                         2000
# 3                     NaN               NaN                          NaN
# 4                  2010.0            2012.0                         2005
#
# [5 rows x 31 columns]

# %%
df_remove.Country_Code #Accesses the Country_Code column from df_remove.
# Out:
# 0     AGO
# 1     ALB
# 2     ARG
# 3     ASM
# 4     AZE
# 5     BGR
# 6     BIH
# 7     BLR
# 8     BLZ
# 9     BRA
# 10    BWA
# 11    CHN
# 12    COL
# 13    CRI
# 14    CUB
# 15    DMA
# 16    DOM
# 17    DZA
# 18    ECU
# 19    FJI
# 20    GAB
# 21    GRD
# 22    HUN
# 23    IRN
# 24    IRQ
# 25    JAM
# 26    JOR
# 27    KAZ
# 28    LBN
# 29    LBY
# 30    LCA
# 31    MDV
# 32    MEX
# 33    MHL
# 34    MKD
# 35    MNE
# 36    MUS
# 37    MYS
# 38    NAM
# 39    PAN
# 40    PER
# 41    PLW
# 42    ROU
# 43    SRB
# 44    SUR
# 45    SYC
# 46    THA
# 47    TKM
# 48    TON
# 49    TUN
# 50    TUR
# 51    TUV
# 52    VCT
# 53    VEN
# 54    ZAF
# Name: Country_Code, dtype: object

# %%
df_remove["Region"].value_counts() #Counts the unique values in the Region column of 'df_remove'.
# Out:
# Region
# Latin America & Caribbean     18
# Europe & Central Asia         13
# East Asia & Pacific            9
# Sub-Saharan Africa             7
# Middle East & North Africa     7
# South Asia                     1
# Name: count, dtype: int64

# %%
df_remove.Region #Accesses the 'Region' column in 'df_remove'.
# Out:
# 0             Sub-Saharan Africa
# 1          Europe & Central Asia
# 2      Latin America & Caribbean
# 3            East Asia & Pacific
# 4          Europe & Central Asia
# 5          Europe & Central Asia
# 6          Europe & Central Asia
# 7          Europe & Central Asia
# 8      Latin America & Caribbean
# 9      Latin America & Caribbean
# 10            Sub-Saharan Africa
# 11           East Asia & Pacific
# 12     Latin America & Caribbean
# 13     Latin America & Caribbean
# 14     Latin America & Caribbean
# 15     Latin America & Caribbean
# 16     Latin America & Caribbean
# 17    Middle East & North Africa
# 18     Latin America & Caribbean
# 19           East Asia & Pacific
# 20            Sub-Saharan Africa
# 21     Latin America & Caribbean
# 22         Europe & Central Asia
# 23    Middle East & North Africa
# 24    Middle East & North Africa
# 25     Latin America & Caribbean
# 26    Middle East & North Africa
# 27         Europe & Central Asia
# 28    Middle East & North Africa
# 29    Middle East & North Africa
# 30     Latin America & Caribbean
# 31                    South Asia
# 32     Latin America & Caribbean
# 33           East Asia & Pacific
# 34         Europe & Central Asia
# 35         Europe & Central Asia
# 36            Sub-Saharan Africa
# 37           East Asia & Pacific
# 38            Sub-Saharan Africa
# 39     Latin America & Caribbean
# 40     Latin America & Caribbean
# 41           East Asia & Pacific
# 42         Europe & Central Asia
# 43         Europe & Central Asia
# 44     Latin America & Caribbean
# 45            Sub-Saharan Africa
# 46           East Asia & Pacific
# 47         Europe & Central Asia
# 48           East Asia & Pacific
# 49    Middle East & North Africa
# 50         Europe & Central Asia
# 51           East Asia & Pacific
# 52     Latin America & Caribbean
# 53     Latin America & Caribbean
# 54            Sub-Saharan Africa
# Name: Region, dtype: object

# %%
df_remove.Region.unique() #Returns the unique values in the Region column of 'df_remove'.
# Out:
# array(['Sub-Saharan Africa', 'Europe & Central Asia',
#        'Latin America & Caribbean', 'East Asia & Pacific',
#        'Middle East & North Africa', 'South Asia'], dtype=object)

# %% [markdown]
# # Statistical Modeling

# %%
df_remove.describe() #Summarize data such as mean, median, or standard deviation for numeric columns
# Out:
#        National_accounts_reference_year  Latest_industrial_ data  \
# count                          7.000000                28.000000
# mean                        2000.142857              2008.642857
# std                            3.287784                 2.376027
# min                         1996.000000              2001.000000
# 25%                         1998.000000              2008.750000
# 50%                         2000.000000              2010.000000
# 75%                         2002.000000              2010.000000
# max                         2005.000000              2010.000000
#
#        Latest_trade_data
# count          50.000000
# mean         2011.140000
# std             2.109357
# min          2000.000000
# 25%          2011.250000
# 50%          2012.000000
# 75%          2012.000000
# max          2012.000000

# %%
df_filtering = df_remove[df_remove.Region=="Europe & Central Asia"] #Show only the "Europe & Central Asia" columns. 
df_filtering.head() #Displays the first 5 rows of df_recet.
# Out:
#   Country_Code              Short_Name              Table_Name  \
# 1          ALB                 Albania                 Albania
# 4          AZE              Azerbaijan              Azerbaijan
# 5          BGR                Bulgaria                Bulgaria
# 6          BIH  Bosnia and Herzegovina  Bosnia and Herzegovina
# 7          BLR                 Belarus                 Belarus
#
#                 Long_Name 2-alpha_code  \
# 1     Republic of Albania           AL
# 4  Republic of Azerbaijan           AZ
# 5    Republic of Bulgaria           BG
# 6  Bosnia and Herzegovina           BA
# 7     Republic of Belarus           BY
#
#                              Currency_Unit  \
# 1                             Albanian lek
# 4                          New Azeri manat
# 5                            Bulgarian lev
# 6  Bosnia and Herzegovina convertible mark
# 7                         Belarusian rubel
#
#                                        Special_Notes                 Region  \
# 1                                                NaN  Europe & Central Asia
# 4  April 2012 database update: National accounts ...  Europe & Central Asia
# 5  April 2011 database update: The National Stati...  Europe & Central Asia
# 6                                                NaN  Europe & Central Asia
# 7                                                NaN  Europe & Central Asia
#
#           Income_Group WB-2_code  ...    Government_Accounting_concept  \
# 1  Upper middle income        AL  ...     Budgetary central government
# 4  Upper middle income        AZ  ...  Consolidated central government
# 5  Upper middle income        BG  ...  Consolidated central government
# 6  Upper middle income        BA  ...  Consolidated central government
# 7  Upper middle income        BY  ...  Consolidated central government
#
#               IMF_data_dissemination_standard Latest_population_census  \
# 1    General Data Dissemination System (GDDS)                     2011
# 4    General Data Dissemination System (GDDS)                     2009
# 5  Special Data Dissemination Standard (SDDS)                     2011
# 6    General Data Dissemination System (GDDS)                     2013
# 7  Special Data Dissemination Standard (SDDS)                     2009
#
#                              Latest_household_survey  \
# 1       Demographic and Health Survey (DHS), 2008/09
# 4          Demographic and Health Survey (DHS), 2006
# 5  Living Standards Measurement Study Survey (LSM...
# 6  Multiple Indicator Cluster Survey (MICS), 2011/12
# 7     Multiple Indicator Cluster Survey (MICS), 2012
#
#    Source_of_most_recent_Income_and_expenditure_data  \
# 1  Living Standards Measurement Study Survey (LSM...
# 4     Expenditure survey/budget survey (ES/BS), 2012
# 5     Expenditure survey/budget survey (ES/BS), 2007
# 6  Living Standards Measurement Study Survey (LSM...
# 7     Expenditure survey/budget survey (ES/BS), 2012
#
#   Vital_registration_complete Latest_agricultural_census  \
# 1                         Yes                       2012
# 4                         Yes                       2015
# 5                         Yes                       2010
# 6                         Yes                        NaN
# 7                         Yes                        NaN
#
#   Latest_industrial_ data Latest_trade_data Latest_water_withdrawal_data
# 1                  2010.0            2012.0                         2006
# 4                  2010.0            2012.0                         2005
# 5                  2010.0            2012.0                         2009
# 6                     NaN            2012.0                         2009
# 7                  2009.0            2012.0                         2000
#
# [5 rows x 31 columns]

# %%
df_filtering.Region.unique() #Returns the unique values in the Region column of 'df_remove'.
# Out:
# array(['Europe & Central Asia'], dtype=object)

# %%
df_filtering =df_filtering.reset_index(drop=True) #Resets 'df_remove' index.
df_filtering.head(20) #Displays the first 20 rows of df_remove.
# Out:
#    Country_Code              Short_Name              Table_Name  \
# 0           ALB                 Albania                 Albania
# 1           AZE              Azerbaijan              Azerbaijan
# 2           BGR                Bulgaria                Bulgaria
# 3           BIH  Bosnia and Herzegovina  Bosnia and Herzegovina
# 4           BLR                 Belarus                 Belarus
# 5           HUN                 Hungary                 Hungary
# 6           KAZ              Kazakhstan              Kazakhstan
# 7           MKD               Macedonia          Macedonia, FYR
# 8           MNE              Montenegro              Montenegro
# 9           ROU                 Romania                 Romania
# 10          SRB                  Serbia                  Serbia
# 11          TKM            Turkmenistan            Turkmenistan
# 12          TUR                  Turkey                  Turkey
#
#                                 Long_Name 2-alpha_code  \
# 0                     Republic of Albania           AL
# 1                  Republic of Azerbaijan           AZ
# 2                    Republic of Bulgaria           BG
# 3                  Bosnia and Herzegovina           BA
# 4                     Republic of Belarus           BY
# 5                                 Hungary           HU
# 6                  Republic of Kazakhstan           KZ
# 7   Former Yugoslav Republic of Macedonia           MK
# 8                              Montenegro           ME
# 9                                 Romania           RO
# 10                     Republic of Serbia           RS
# 11                           Turkmenistan           TM
# 12                     Republic of Turkey           TR
#
#                               Currency_Unit  \
# 0                              Albanian lek
# 1                           New Azeri manat
# 2                             Bulgarian lev
# 3   Bosnia and Herzegovina convertible mark
# 4                          Belarusian rubel
# 5                          Hungarian forint
# 6                              Kazakh tenge
# 7                          Macedonian denar
# 8                                      Euro
# 9                          New Romanian leu
# 10                        New Serbian dinar
# 11                        New Turkmen manat
# 12                         New Turkish lira
#
#                                         Special_Notes                 Region  \
# 0                                                 NaN  Europe & Central Asia
# 1   April 2012 database update: National accounts ...  Europe & Central Asia
# 2   April 2011 database update: The National Stati...  Europe & Central Asia
# 3                                                 NaN  Europe & Central Asia
# 4                                                 NaN  Europe & Central Asia
# 5   April 2012 database update: Based on data from...  Europe & Central Asia
# 6                                                 NaN  Europe & Central Asia
# 7   April 2012 database update: Based on official ...  Europe & Central Asia
# 8   Montenegro declared independence from Serbia a...  Europe & Central Asia
# 9   National accounts have been revised based on d...  Europe & Central Asia
# 10  Montenegro declared independence from Serbia a...  Europe & Central Asia
# 11  On January 1, 2009, the Turkmen manat was rede...  Europe & Central Asia
# 12                                                NaN  Europe & Central Asia
#
#            Income_Group WB-2_code  ...    Government_Accounting_concept  \
# 0   Upper middle income        AL  ...     Budgetary central government
# 1   Upper middle income        AZ  ...  Consolidated central government
# 2   Upper middle income        BG  ...  Consolidated central government
# 3   Upper middle income        BA  ...  Consolidated central government
# 4   Upper middle income        BY  ...  Consolidated central government
# 5   Upper middle income        HU  ...  Consolidated central government
# 6   Upper middle income        KZ  ...  Consolidated central government
# 7   Upper middle income        MK  ...  Consolidated central government
# 8   Upper middle income        ME  ...                              NaN
# 9   Upper middle income        RO  ...  Consolidated central government
# 10  Upper middle income        YF  ...  Consolidated central government
# 11  Upper middle income        TM  ...                              NaN
# 12  Upper middle income        TR  ...  Consolidated central government
#
#                IMF_data_dissemination_standard Latest_population_census  \
# 0     General Data Dissemination System (GDDS)                     2011
# 1     General Data Dissemination System (GDDS)                     2009
# 2   Special Data Dissemination Standard (SDDS)                     2011
# 3     General Data Dissemination System (GDDS)                     2013
# 4   Special Data Dissemination Standard (SDDS)                     2009
# 5   Special Data Dissemination Standard (SDDS)                     2011
# 6   Special Data Dissemination Standard (SDDS)                     2009
# 7   Special Data Dissemination Standard (SDDS)                     2002
# 8     General Data Dissemination System (GDDS)                     2011
# 9   Special Data Dissemination Standard (SDDS)                     2011
# 10    General Data Dissemination System (GDDS)                     2011
# 11                                         NaN                     2012
# 12  Special Data Dissemination Standard (SDDS)                     2011
#
#                               Latest_household_survey  \
# 0        Demographic and Health Survey (DHS), 2008/09
# 1           Demographic and Health Survey (DHS), 2006
# 2   Living Standards Measurement Study Survey (LSM...
# 3   Multiple Indicator Cluster Survey (MICS), 2011/12
# 4      Multiple Indicator Cluster Survey (MICS), 2012
# 5                     World Health Survey (WHS), 2003
# 6   Multiple Indicator Cluster Survey (MICS), 2010/11
# 7      Multiple Indicator Cluster Survey (MICS), 2011
# 8   Multiple Indicator Cluster Survey (MICS), 2005/06
# 9              Reproductive Health Survey (RHS), 1999
# 10     Multiple Indicator Cluster Survey (MICS), 2010
# 11     Multiple Indicator Cluster Survey (MICS), 2011
# 12  Demographic and Health Survey (DHS), 2003; Wor...
#
#     Source_of_most_recent_Income_and_expenditure_data  \
# 0   Living Standards Measurement Study Survey (LSM...
# 1      Expenditure survey/budget survey (ES/BS), 2012
# 2      Expenditure survey/budget survey (ES/BS), 2007
# 3   Living Standards Measurement Study Survey (LSM...
# 4      Expenditure survey/budget survey (ES/BS), 2012
# 5      Expenditure survey/budget survey (ES/BS), 2007
# 6      Expenditure survey/budget survey (ES/BS), 2012
# 7      Expenditure survey/budget survey (ES/BS), 2009
# 8      Expenditure survey/budget survey (ES/BS), 2011
# 9                      Labor force survey (LFS), 2010
# 10            Integrated household survey (IHS), 2010
# 11  Living Standards Measurement Study Survey (LSM...
# 12                     Labor force survey (LFS), 2009
#
#    Vital_registration_complete Latest_agricultural_census  \
# 0                          Yes                       2012
# 1                          Yes                       2015
# 2                          Yes                       2010
# 3                          Yes                        NaN
# 4                          Yes                        NaN
# 5                          Yes                       2010
# 6                          Yes                        NaN
# 7                          Yes                       2007
# 8                          Yes                       2010
# 9                          Yes                       2010
# 10                         Yes                       2012
# 11                         Yes                        NaN
# 12                         NaN                        NaN
#
#    Latest_industrial_ data Latest_trade_data Latest_water_withdrawal_data
# 0                   2010.0            2012.0                         2006
# 1                   2010.0            2012.0                         2005
# 2                   2010.0            2012.0                         2009
# 3                      NaN            2012.0                         2009
# 4                   2009.0            2012.0                         2000
# 5                   2009.0            2012.0                         2007
# 6                      NaN            2012.0                         2010
# 7                   2010.0            2012.0                         2007
# 8                      NaN            2012.0                         2010
# 9                   2010.0            2012.0                         2009
# 10                  2010.0               NaN                         2009
# 11                     NaN            2000.0                         2004
# 12                  2009.0            2012.0                         2003
#
# [13 rows x 31 columns]

# %%
df_filtering.Region #Accesses the 'Region' column in 'df_remove'.
# Out:
# 0     Europe & Central Asia
# 1     Europe & Central Asia
# 2     Europe & Central Asia
# 3     Europe & Central Asia
# 4     Europe & Central Asia
# 5     Europe & Central Asia
# 6     Europe & Central Asia
# 7     Europe & Central Asia
# 8     Europe & Central Asia
# 9     Europe & Central Asia
# 10    Europe & Central Asia
# 11    Europe & Central Asia
# 12    Europe & Central Asia
# Name: Region, dtype: object

# %%
df_filtering.Country_Code #Accesses the Country_Code column from df_remove.
# Out:
# 0     ALB
# 1     AZE
# 2     BGR
# 3     BIH
# 4     BLR
# 5     HUN
# 6     KAZ
# 7     MKD
# 8     MNE
# 9     ROU
# 10    SRB
# 11    TKM
# 12    TUR
# Name: Country_Code, dtype: object

# %%
df_filtering.info() #That will print information on all the columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 31 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country_Code                                       13 non-null     object
#  1   Short_Name                                         13 non-null     object
#  2   Table_Name                                         13 non-null     object
#  3   Long_Name                                          13 non-null     object
#  4   2-alpha_code                                       13 non-null     object
#  5   Currency_Unit                                      13 non-null     object
#  6   Special_Notes                                      8 non-null      object
#  7   Region                                             13 non-null     object
#  8   Income_Group                                       13 non-null     object
#  9   WB-2_code                                          13 non-null     object
#  10  National_accounts_base_year                        13 non-null     object
#  11  National_accounts_reference_year                   7 non-null      float64
#  12  SNA_price_valuation                                13 non-null     object
#  13  Lending_category                                   12 non-null     object
#  14  Other_groups                                       0 non-null      object
#  15  System_of_National_Accounts                        13 non-null     object
#  16  Alternative_conversion_factor                      6 non-null      object
#  17  PPP_survey_year                                    12 non-null     object
#  18  Balance_of_Payments_Manual_in_use                  13 non-null     object
#  19  External_debt_Reporting_status                     13 non-null     object
#  20  System_of_trade                                    13 non-null     object
#  21  Government_Accounting_concept                      11 non-null     object
#  22  IMF_data_dissemination_standard                    12 non-null     object
#  23  Latest_population_census                           13 non-null     object
#  24  Latest_household_survey                            13 non-null     object
#  25  Source_of_most_recent_Income_and_expenditure_data  13 non-null     object
#  26  Vital_registration_complete                        12 non-null     object
#  27  Latest_agricultural_census                         8 non-null      object
#  28  Latest_industrial_ data                            9 non-null      float64
#  29  Latest_trade_data                                  12 non-null     float64
#  30  Latest_water_withdrawal_data                       13 non-null     object
# dtypes: float64(3), object(28)
# memory usage: 3.3+ KB

# %%
# Save the filtered DataFrame as a CSV file
df_filtering.to_csv('filtering.EdStatsCountry_data.csv', index=False)  # Set index=False to avoid saving the index as a separate column

# %% [markdown]
# # Statistical Modeling

# %%
df_filtering.describe() #Summarize data such as mean, median, or standard deviation for numeric columns
# Out:
#        National_accounts_reference_year  Latest_industrial_ data  \
# count                          7.000000                 9.000000
# mean                        2000.142857              2009.666667
# std                            3.287784                 0.500000
# min                         1996.000000              2009.000000
# 25%                         1998.000000              2009.000000
# 50%                         2000.000000              2010.000000
# 75%                         2002.000000              2010.000000
# max                         2005.000000              2010.000000
#
#        Latest_trade_data
# count          12.000000
# mean         2011.000000
# std             3.464102
# min          2000.000000
# 25%          2012.000000
# 50%          2012.000000
# 75%          2012.000000
# max          2012.000000
